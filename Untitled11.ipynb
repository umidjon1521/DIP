# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /opt/anaconda3/lib/python3.12/site-packages (4.13.0.92)
# Requirement already satisfied: numpy>=2 in /opt/anaconda3/lib/python3.12/site-packages (from opencv-python) (2.4.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.12/site-packages (2.4.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def show(title, img, cmap='gray'):
    plt.figure(figsize=(5,5))
    plt.title(title)
    plt.imshow(img, cmap=cmap)
    plt.axis('off')
    plt.show()

# %%
finger = cv2.imread('/Users/umidjongofurov/Downloads/finger.png', cv2.IMREAD_GRAYSCALE)
text = cv2.imread('/Users/umidjongofurov/Downloads/text.png', cv2.IMREAD_GRAYSCALE)

show("Оригинальный Fingerprint", finger)
show("Оригинальный Text", text)

# %%
noise_finger = np.random.randint(0, 256, finger.shape, dtype=np.uint8)
noisy_finger = cv2.addWeighted(finger, 0.8, noise_finger, 0.2, 0)
show("Noisy Fingerprint", noisy_finger)

noise_text = np.random.randint(0, 256, text.shape, dtype=np.uint8)
noisy_text = cv2.addWeighted(text, 0.8, noise_text, 0.2, 0)
show("Noisy Text", noisy_text)

# %%
_, thresh_finger = cv2.threshold(noisy_finger, 127, 255, cv2.THRESH_BINARY)
show("Thresholded Fingerprint", thresh_finger)

_, thresh_text = cv2.threshold(noisy_text, 127, 255, cv2.THRESH_BINARY)
show("Thresholded Text", thresh_text)

# %%
median_finger = cv2.medianBlur(noisy_finger, 3)
show("Median Filtered Fingerprint", median_finger)

median_text = cv2.medianBlur(noisy_text, 3)
show("Median Filtered Text", median_text)

# %%
kernel = np.ones((3,3), np.uint8)
closing_finger = cv2.morphologyEx(median_finger, cv2.MORPH_CLOSE, kernel)
show("Closing Fingerprint", closing_finger)

# %%
opening_text = cv2.morphologyEx(median_text, cv2.MORPH_OPEN, kernel)
show("Opening Text", opening_text)

closing_text = cv2.morphologyEx(opening_text, cv2.MORPH_CLOSE, kernel)
show("Final Clean Text", closing_text)

# %%
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.title("Original Fingerprint")
plt.imshow(finger, cmap='gray')
plt.axis('off')

plt.subplot(1,2,2)
plt.title("Processed Fingerprint")
plt.imshow(closing_finger, cmap='gray')
plt.axis('off')

plt.show()
